# %%
import pandas as pd
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("pokemon_data.csv")

# %%
df.head
# Out:
# <bound method NDFrame.head of        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 12 columns]>

# %%
#df.loc[df["Type 2"] == "Poison"]
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 12 columns]

# %%
df.sort_values(["Name", "Defense"], ascending=[0,1])
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 794       81       95     95           6       True
# 695       65       70     58           5      False
# 46        30       40     55           1      False
# 631       80       40     65           5      False
# 632      120       60    105           5      False
# ..       ...      ...    ...         ...        ...
# 393      115       60    115           3      False
# 392       75       60     75           3      False
# 68       105       55     90           1      False
# 511      132      105     30           4      False
# 510       92       85     60           4      False
#
# [800 rows x 12 columns]

# %%
df["Atk/Def Ratio"] = (df["Attack"] / df["Defense"])
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Atk/Def Ratio
# 0       65     45           1      False       1.000000
# 1       80     60           1      False       0.984127
# 2      100     80           1      False       0.987952
# 3      120     80           1      False       0.813008
# 4       50     65           1      False       1.209302

# %%
df.loc[(df["Type 1"] == "Grass") & (df["Type 2"] == "Poison")]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 48    43                 Oddish  Grass  Poison   45      50       55       75
# 49    44                  Gloom  Grass  Poison   60      65       70       85
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 75    69             Bellsprout  Grass  Poison   50      75       35       70
# 76    70             Weepinbell  Grass  Poison   65      90       50       85
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 344  315                Roselia  Grass  Poison   50      60       45      100
# 451  406                  Budew  Grass  Poison   40      30       35       50
# 452  407               Roserade  Grass  Poison   60      70       65      125
# 651  590                Foongus  Grass  Poison   69      55       45       55
# 652  591              Amoonguss  Grass  Poison  114      85       70       85
#
#      Sp. Def  Speed  Generation  Legendary  Atk/Def Ratio
# 0         65     45           1      False       1.000000
# 1         80     60           1      False       0.984127
# 2        100     80           1      False       0.987952
# 3        120     80           1      False       0.813008
# 48        65     30           1      False       0.909091
# 49        75     40           1      False       0.928571
# 50        90     50           1      False       0.941176
# 75        30     40           1      False       2.142857
# 76        45     55           1      False       1.800000
# 77        70     70           1      False       1.615385
# 344       80     65           3      False       1.333333
# 451       70     55           4      False       0.857143
# 452      105     90           4      False       1.076923
# 651       55     15           5      False       1.222222
# 652       80     30           5      False       1.214286

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Atk/Def Ratio
# 0         65       65     45           1      False       1.000000
# 1         80       80     60           1      False       0.984127
# 2        100      100     80           1      False       0.987952
# 3        122      120     80           1      False       0.813008
# 4         60       50     65           1      False       1.209302
# ..       ...      ...    ...         ...        ...            ...
# 795      100      150     50           6       True       0.666667
# 796      160      110    110           6       True       1.454545
# 797      150      130     70           6       True       1.833333
# 798      170      130     80           6       True       2.666667
# 799      130       90     70           6       True       0.916667
#
# [800 rows x 13 columns]

# %%
df.loc[df["Name"].str.contains('Mega')]
# Out:
#        #                       Name    Type 1    Type 2   HP  Attack  Defense  \
# 3      3      VenusaurMega Venusaur     Grass    Poison   80     100      123
# 7      6  CharizardMega Charizard X      Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y      Fire    Flying   78     104       78
# 12     9    BlastoiseMega Blastoise     Water       NaN   79     103      120
# 19    15      BeedrillMega Beedrill       Bug    Poison   65     150       40
# 23    18        PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 71    65      AlakazamMega Alakazam   Psychic       NaN   55      50       65
# 87    80        SlowbroMega Slowbro     Water   Psychic   95      75      180
# 102   94          GengarMega Gengar     Ghost    Poison   60      65       80
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN  105     125      100
# 137  127          PinsirMega Pinsir       Bug    Flying   65     155      120
# 141  130      GyaradosMega Gyarados     Water      Dark   95     155      109
# 154  142  AerodactylMega Aerodactyl      Rock    Flying   80     135       85
# 163  150        MewtwoMega Mewtwo X   Psychic  Fighting  106     190      100
# 164  150        MewtwoMega Mewtwo Y   Psychic       NaN  106     150       70
# 168  154                   Meganium     Grass       NaN   80      82      100
# 196  181      AmpharosMega Ampharos  Electric    Dragon   90      95      105
# 224  208        SteelixMega Steelix     Steel    Ground   75     125      230
# 229  212          ScizorMega Scizor       Bug     Steel   70     150      140
# 232  214    HeracrossMega Heracross       Bug  Fighting   80     185      115
# 248  229      HoundoomMega Houndoom      Dark      Fire   75      90       90
# 268  248    TyranitarMega Tyranitar      Rock      Dark  100     164      150
# 275  254      SceptileMega Sceptile     Grass    Dragon   70     110       75
# 279  257      BlazikenMega Blaziken      Fire  Fighting   80     160       80
# 283  260      SwampertMega Swampert     Water    Ground  100     150      110
# 306  282    GardevoirMega Gardevoir   Psychic     Fairy   68      85       65
# 327  302        SableyeMega Sableye      Dark     Ghost   50      85      125
# 329  303          MawileMega Mawile     Steel     Fairy   50     105      125
# 333  306          AggronMega Aggron     Steel       NaN   70     140      230
# 336  308      MedichamMega Medicham  Fighting   Psychic   60     100       85
# 339  310    ManectricMega Manectric  Electric       NaN   70      75       80
# 349  319      SharpedoMega Sharpedo     Water      Dark   70     140       70
# 354  323      CameruptMega Camerupt      Fire    Ground   70     120      100
# 366  334        AltariaMega Altaria    Dragon     Fairy   75     110      110
# 387  354        BanetteMega Banette     Ghost       NaN   64     165       75
# 393  359            AbsolMega Absol      Dark       NaN   65     150       60
# 397  362          GlalieMega Glalie       Ice       NaN   80     120       80
# 409  373    SalamenceMega Salamence    Dragon    Flying   95     145      130
# 413  376    MetagrossMega Metagross     Steel   Psychic   80     145      150
# 418  380          LatiasMega Latias    Dragon   Psychic   80     100      120
# 420  381          LatiosMega Latios    Dragon   Psychic   80     130      100
# 426  384      RayquazaMega Rayquaza    Dragon    Flying  105     180      100
# 476  428        LopunnyMega Lopunny    Normal  Fighting   65     136       94
# 494  445      GarchompMega Garchomp    Dragon    Ground  108     170      115
# 498  448        LucarioMega Lucario  Fighting     Steel   70     145       88
# 511  460    AbomasnowMega Abomasnow     Grass       Ice   90     132      105
# 527  475        GalladeMega Gallade   Psychic  Fighting   68     165       95
# 591  531          AudinoMega Audino    Normal     Fairy  103      60      126
# 796  719        DiancieMega Diancie      Rock     Fairy   50     160      110
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Atk/Def Ratio
# 3        122      120     80           1      False       0.813008
# 7        130       85    100           1      False       1.171171
# 8        159      115    100           1      False       1.333333
# 12       135      115     78           1      False       0.858333
# 19        15       80    145           1      False       3.750000
# 23       135       80    121           1      False       1.000000
# 71       175       95    150           1      False       0.769231
# 87       130       80     30           1      False       0.416667
# 102      170       95    130           1      False       0.812500
# 124       60      100    100           1      False       1.250000
# 137       65       90    105           1      False       1.291667
# 141       70      130     81           1      False       1.422018
# 154       70       95    150           1      False       1.588235
# 163      154      100    130           1       True       1.900000
# 164      194      120    140           1       True       2.142857
# 168       83      100     80           2      False       0.820000
# 196      165      110     45           2      False       0.904762
# 224       55       95     30           2      False       0.543478
# 229       65      100     75           2      False       1.071429
# 232       40      105     75           2      False       1.608696
# 248      140       90    115           2      False       1.000000
# 268       95      120     71           2      False       1.093333
# 275      145       85    145           3      False       1.466667
# 279      130       80    100           3      False       2.000000
# 283       95      110     70           3      False       1.363636
# 306      165      135    100           3      False       1.307692
# 327       85      115     20           3      False       0.680000
# 329       55       95     50           3      False       0.840000
# 333       60       80     50           3      False       0.608696
# 336       80       85    100           3      False       1.176471
# 339      135       80    135           3      False       0.937500
# 349      110       65    105           3      False       2.000000
# 354      145      105     20           3      False       1.200000
# 366      110      105     80           3      False       1.000000
# 387       93       83     75           3      False       2.200000
# 393      115       60    115           3      False       2.500000
# 397      120       80    100           3      False       1.500000
# 409      120       90    120           3      False       1.115385
# 413      105      110    110           3      False       0.966667
# 418      140      150    110           3       True       0.833333
# 420      160      120    110           3       True       1.300000
# 426      180      100    115           3       True       1.800000
# 476       54       96    135           4      False       1.446809
# 494      120       95     92           4      False       1.478261
# 498      140       70    112           4      False       1.647727
# 511      132      105     30           4      False       1.257143
# 527       65      115    110           4      False       1.736842
# 591       80      126     50           5      False       0.476190
# 796      160      110    110           6       True       1.454545
